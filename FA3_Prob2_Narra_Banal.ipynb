# %% [markdown]
# <a href="https://colab.research.google.com/github/smlbanal31-afk/samplepythonactivities/blob/main/FA3_Prob2_Narra_Banal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
credits_score = int(input("Enter credit score: "))
annual_income = float(input("Enter annual income: "))
years_at_job = int(input("Enter years at current job: "))

if credits_score >= 700 and annual_income >= 30000 and years_at_job>= 2:
    print("Loan approved.")

else:
     print("Loan denied.")
# Out:
# Enter credit score: 710
# Enter annual income: 350000
# Enter years at current job: 3
# Loan approved.
