# %% [markdown]
# <a href="https://colab.research.google.com/github/smlbanal31-afk/samplepythonactivities/blob/main/FA3_NARRA_BANAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
password = input("Enter your password: ")
length = len(password)

if length >= 8 and length <= 15:
    print("Password length is valid.")

else:
    print("Password is too short or too long.Try again")
# Out:
# Enter your password: strongPass12
# Password length is valid.
